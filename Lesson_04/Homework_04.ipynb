# %%
import re
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from pymongo import MongoClient
from pprint import pprint

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Задание №1

# %% [markdown]
# Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии в созданную БД

# %% [markdown]
# Так как у нас зарплата на hh.ru может быть представлена в разных форматах (160 000-250 000 руб., 2 000-3 000 EUR и тп), то ее нужно привести к единому формату, чтобы вдальнейшем можно было производить различные манипуляции с данными. Делаем допущение и зашиваем жестко курс валюты, хотя можно было и его спарсить.

# %%
def hh_salary_parse(salary):
    currency = 1
    if 'USD' in salary:
        currency = 63.58
    if 'EUR' in salary:
        currency = 71.66
    if salary == 'Не указанно':
        salary = '0.0'
    salary = salary.replace(' ', '')    
    salary = salary[:salary.find('-')]
    salary = re.findall("\d+", salary)
    salary = float(salary[0]) * currency
    return salary

# %%
def hh_parse(vacancy_name, search_depth, analysis_period):
    n = 0
    titles = []
    salarys = []
    salarys_processed = []
    hrefs = []
    
    hh_url = 'https://hh.ru/search/vacancy?search_period='+str(analysis_period)+'&text='+vacancy_name+'&area=1'
    headers = {'accept': '*/*',
           'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.1.1 Safari/605.1.15'}
    
    session = requests.session()
    
    while n < search_depth:
        request = session.get(hh_url+'&page='+str(n), headers=headers)
        hh_html = bs(request.content, 'html.parser')
        divs = hh_html.find_all('div', attrs={'data-qa': 'vacancy-serp__vacancy'})
        for div in divs:
            title = div.find('a', attrs={'data-qa': 'vacancy-serp__vacancy-title'}).text
            salary = div.find('div', attrs={'data-qa': 'vacancy-serp__vacancy-compensation'})
            if salary == None:
                salary = 'Не указанно'
            else:
                salary = div.find('div', attrs={'data-qa': 'vacancy-serp__vacancy-compensation'}).text

            href = div.find('a', attrs={'data-qa': 'vacancy-serp__vacancy-title'})['href']
            salary_processed = hh_salary_parse(salary) * 1000
            titles.append(title)
            salarys.append(salary)
            salarys_processed.append(salary_processed)
            hrefs.append(href)
        n += 1
    df = pd.DataFrame({'Title': titles,
                       'Salary': salarys,
                       'Salary_Processed': salarys_processed,
                       'Href': hrefs}, columns=['Title', 'Salary', 'Salary_Processed', 'Href'])
    df.replace(u'\xa0', u'', regex=True, inplace=True)
    return df

# %%
vacancy_name = input('Введите название вакансии для поиска: ')
# Out:
# Введите название вакансии для поиска: python

# %%
search_depth = int(input('Введите глубину поиска (количество страниц): '))
# Out:
# Введите глубину поиска (количество страниц): 2

# %%
analysis_period = int(input('Введите период анализа (количество дней): '))
# Out:
# Введите период анализа (количество дней): 10

# %%
hh_frame = hh_parse(vacancy_name, search_depth, analysis_period)

# %%
hh_frame
# Out:
#                                                 Title              Salary  \
# 0                                    Python Developer  160000-250000 руб.
# 1                         Программист Python (в Ригу)       2000-3000 EUR
# 2                                  Программист Python   75000-110000 руб.
# 3                                  Программист Python   60000-100000 руб.
# 4                            Разработчик Python и SQL      от 180000 руб.
# 5                                  Python-разработчик      от 100000 руб.
# 6                                  Разработчик Python  160000-200000 руб.
# 7                           Python/Django разработчик   60000-100000 руб.
# 8                          Ведущий Python разработчик  150000-250000 руб.
# 9                Разработчик Python/Django + React.js  145000-255000 руб.
# 10                                 Программист Python      от 150000 руб.
# 11                                 Разработчик Python         Не указанно
# 12                                 Разработчик Python  120000-180000 руб.
# 13                                 Python-разработчик         Не указанно
# 14           Программист / Ведущий программист Python      от 160000 руб.
# 15  Python developer (Библиотеки для автотестирова...         от 4000 USD
# 16  Senior python developer в Трипстер (Python, Dj...         Не указанно
# 17                                 Программист Python  100000-180000 руб.
# 18                                 Разработчик Python      от 140000 руб.
# 19                             Программист Python/C++   70000-100000 руб.
# 20                              Python Data Scientist      от 150000 руб.
# 21                                 Разработчик Python  150000-200000 руб.
# 22                                 Python-разработчик      до 130000 руб.
# 23                       Разработчик Python/Team-lead  120000-200000 руб.
# 24                                 Программист Python   80000-130000 руб.
# 25                            Senior Python Developer  150000-220000 руб.
# 26          Data Engineering Team Lead (Python / C++)  300000-400000 руб.
# 27                                 Разработчик Python       от 95000 руб.
# 28           Senior Python developer (Cloud Services)  180000-230000 руб.
# 29                  Python developer (Cloud Services)  150000-230000 руб.
# 30                               Python Web Developer  200000-300000 руб.
# 31             Full-stack разработчик Django / Python   90000-120000 руб.
# 32  Ведущий разработчик Python на платежную платформу      от 200000 руб.
# 33                            Программист Python, C++   90000-140000 руб.
# 34                          Python Developer (Django)         Не указанно
# 35                                   Python Developer         Не указанно
# 36                         Ведущий разработчик Python         Не указанно
#
#     Salary_Processed                                               Href
# 0           160000.0  https://vidnoe.hh.ru/vacancy/32072763?query=py...
# 1           143320.0  https://vidnoe.hh.ru/vacancy/32079548?query=py...
# 2            75000.0  https://vidnoe.hh.ru/vacancy/31347220?query=py...
# 3            60000.0  https://vidnoe.hh.ru/vacancy/32260756?query=py...
# 4           180000.0  https://vidnoe.hh.ru/vacancy/31929637?query=py...
# 5           100000.0  https://vidnoe.hh.ru/vacancy/32251802?query=py...
# 6           160000.0  https://vidnoe.hh.ru/vacancy/31624245?query=py...
# 7            60000.0  https://vidnoe.hh.ru/vacancy/32158934?query=py...
# 8           150000.0  https://vidnoe.hh.ru/vacancy/32061372?query=py...
# 9           145000.0  https://vidnoe.hh.ru/vacancy/31844761?query=py...
# 10          150000.0  https://vidnoe.hh.ru/vacancy/32304134?query=py...
# 11               0.0  https://vidnoe.hh.ru/vacancy/31865378?query=py...
# 12          120000.0  https://vidnoe.hh.ru/vacancy/30451399?query=py...
# 13               0.0  https://vidnoe.hh.ru/vacancy/32262922?query=py...
# 14          160000.0  https://vidnoe.hh.ru/vacancy/32317115?query=py...
# 15          254320.0  https://vidnoe.hh.ru/vacancy/30005963?query=py...
# 16               0.0  https://vidnoe.hh.ru/vacancy/31484508?query=py...
# 17          100000.0  https://vidnoe.hh.ru/vacancy/32139253?query=py...
# 18          140000.0  https://vidnoe.hh.ru/vacancy/31194079?query=py...
# 19           70000.0  https://vidnoe.hh.ru/vacancy/32309858?query=py...
# 20          150000.0  https://vidnoe.hh.ru/vacancy/32068519?query=py...
# 21          150000.0  https://vidnoe.hh.ru/vacancy/31566378?query=py...
# 22          130000.0  https://vidnoe.hh.ru/vacancy/31965654?query=py...
# 23          120000.0  https://vidnoe.hh.ru/vacancy/31974215?query=py...
# 24           80000.0  https://vidnoe.hh.ru/vacancy/30615541?query=py...
# 25          150000.0  https://vidnoe.hh.ru/vacancy/31987135?query=py...
# 26          300000.0  https://vidnoe.hh.ru/vacancy/32030680?query=py...
# 27           95000.0  https://vidnoe.hh.ru/vacancy/31559789?query=py...
# 28          180000.0  https://vidnoe.hh.ru/vacancy/32152220?query=py...
# 29          150000.0  https://vidnoe.hh.ru/vacancy/31952519?query=py...
# 30          200000.0  https://vidnoe.hh.ru/vacancy/32096105?query=py...
# 31           90000.0  https://vidnoe.hh.ru/vacancy/32079250?query=py...
# 32          200000.0  https://vidnoe.hh.ru/vacancy/32256640?query=py...
# 33           90000.0  https://vidnoe.hh.ru/vacancy/30616175?query=py...
# 34               0.0  https://vidnoe.hh.ru/vacancy/32214001?query=py...
# 35               0.0  https://vidnoe.hh.ru/vacancy/31380970?query=py...
# 36               0.0  https://vidnoe.hh.ru/vacancy/31911539?query=py...

# %% [markdown]
# После того как получили данные с hh.ru и вывели их на экран, теперь сохраним их в MongoDB

# %%
client = MongoClient('mongodb://127.0.0.1:27017')
db = client['headhanter']
hhdb = db.headhanter

# %%
for index, row in hh_frame.iterrows():
    hh_data={
        'Title': row['Title'],
        'Salary': row['Salary'],
        'Salary_Processed': row['Salary_Processed'],
        'Href': row['Href']
    }
    hhdb.insert(hh_data)

# %%
hhdb.headhanter
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'headhanter'), 'headhanter.headhanter')

# %% [markdown]
# Проверяем что данные записали в базу, вывод первые 5 записей

# %%
for vacancy in hhdb.find().limit(5):
    pprint(vacancy)
# Out:
# {'Href': 'https://vidnoe.hh.ru/vacancy/32072763?query=python',
#  'Salary': '160000-250000 руб.',
#  'Salary_Processed': 160000.0,
#  'Title': 'Python Developer',
#  '_id': ObjectId('5d1fd100f943af417829c7a5')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32079548?query=python',
#  'Salary': '2000-3000 EUR',
#  'Salary_Processed': 143320.0,
#  'Title': 'Программист Python (в Ригу)',
#  '_id': ObjectId('5d1fd101f943af417829c7a6')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31347220?query=python',
#  'Salary': '75000-110000 руб.',
#  'Salary_Processed': 75000.0,
#  'Title': 'Программист Python',
#  '_id': ObjectId('5d1fd101f943af417829c7a7')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32260756?query=python',
#  'Salary': '60000-100000 руб.',
#  'Salary_Processed': 60000.0,
#  'Title': 'Программист Python',
#  '_id': ObjectId('5d1fd101f943af417829c7a8')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31929637?query=python',
#  'Salary': 'от 180000 руб.',
#  'Salary_Processed': 180000.0,
#  'Title': 'Разработчик Python и SQL',
#  '_id': ObjectId('5d1fd101f943af417829c7a9')}

# %% [markdown]
# ### Задание №2

# %% [markdown]
# Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введенной суммы

# %%
salary_threshold = float(input('Введите пороговую зарплату в рублях, выше которой будет осуществлять поиск: '))
# Out:
# Введите пороговую зарплату в рублях, выше которой будет осуществлять поиск: 100000

# %%
for vacancy in hhdb.find().sort('Salary_Processed').where('this.Salary_Processed >' + str(salary_threshold)):
    pprint(vacancy)
# Out:
# {'Href': 'https://vidnoe.hh.ru/vacancy/30451399?query=python',
#  'Salary': '120000-180000 руб.',
#  'Salary_Processed': 120000.0,
#  'Title': 'Разработчик Python',
#  '_id': ObjectId('5d1fd101f943af417829c7b1')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31974215?query=python',
#  'Salary': '120000-200000 руб.',
#  'Salary_Processed': 120000.0,
#  'Title': 'Разработчик Python/Team-lead',
#  '_id': ObjectId('5d1fd101f943af417829c7bc')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/30451399?query=python',
#  'Salary': '120000-180000 руб.',
#  'Salary_Processed': 120000.0,
#  'Title': 'Разработчик Python',
#  '_id': ObjectId('5d1fd12b99135287c93f0b34')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31974215?query=python',
#  'Salary': '120000-200000 руб.',
#  'Salary_Processed': 120000.0,
#  'Title': 'Разработчик Python/Team-lead',
#  '_id': ObjectId('5d1fd12b99135287c93f0b3f')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31965654?query=python',
#  'Salary': 'до 130000 руб.',
#  'Salary_Processed': 130000.0,
#  'Title': 'Python-разработчик',
#  '_id': ObjectId('5d1fd101f943af417829c7bb')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31965654?query=python',
#  'Salary': 'до 130000 руб.',
#  'Salary_Processed': 130000.0,
#  'Title': 'Python-разработчик',
#  '_id': ObjectId('5d1fd12b99135287c93f0b3e')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31194079?query=python',
#  'Salary': 'от 140000 руб.',
#  'Salary_Processed': 140000.0,
#  'Title': 'Разработчик Python',
#  '_id': ObjectId('5d1fd101f943af417829c7b7')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31194079?query=python',
#  'Salary': 'от 140000 руб.',
#  'Salary_Processed': 140000.0,
#  'Title': 'Разработчик Python',
#  '_id': ObjectId('5d1fd12b99135287c93f0b3a')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32079548?query=python',
#  'Salary': '2000-3000 EUR',
#  'Salary_Processed': 143320.0,
#  'Title': 'Программист Python (в Ригу)',
#  '_id': ObjectId('5d1fd101f943af417829c7a6')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32079548?query=python',
#  'Salary': '2000-3000 EUR',
#  'Salary_Processed': 143320.0,
#  'Title': 'Программист Python (в Ригу)',
#  '_id': ObjectId('5d1fd12b99135287c93f0b29')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31844761?query=python',
#  'Salary': '145000-255000 руб.',
#  'Salary_Processed': 145000.0,
#  'Title': 'Разработчик Python/Django + React.js',
#  '_id': ObjectId('5d1fd101f943af417829c7ae')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31844761?query=python',
#  'Salary': '145000-255000 руб.',
#  'Salary_Processed': 145000.0,
#  'Title': 'Разработчик Python/Django + React.js',
#  '_id': ObjectId('5d1fd12b99135287c93f0b31')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32061372?query=python',
#  'Salary': '150000-250000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Ведущий Python разработчик',
#  '_id': ObjectId('5d1fd101f943af417829c7ad')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32304134?query=python',
#  'Salary': 'от 150000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Программист Python',
#  '_id': ObjectId('5d1fd101f943af417829c7af')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32068519?query=python',
#  'Salary': 'от 150000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Python Data Scientist',
#  '_id': ObjectId('5d1fd101f943af417829c7b9')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31566378?query=python',
#  'Salary': '150000-200000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Разработчик Python',
#  '_id': ObjectId('5d1fd101f943af417829c7ba')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31987135?query=python',
#  'Salary': '150000-220000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Senior Python Developer',
#  '_id': ObjectId('5d1fd101f943af417829c7be')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31952519?query=python',
#  'Salary': '150000-230000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Python developer (Cloud Services)',
#  '_id': ObjectId('5d1fd101f943af417829c7c2')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32061372?query=python',
#  'Salary': '150000-250000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Ведущий Python разработчик',
#  '_id': ObjectId('5d1fd12b99135287c93f0b30')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32304134?query=python',
#  'Salary': 'от 150000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Программист Python',
#  '_id': ObjectId('5d1fd12b99135287c93f0b32')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32068519?query=python',
#  'Salary': 'от 150000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Python Data Scientist',
#  '_id': ObjectId('5d1fd12b99135287c93f0b3c')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31566378?query=python',
#  'Salary': '150000-200000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Разработчик Python',
#  '_id': ObjectId('5d1fd12b99135287c93f0b3d')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31987135?query=python',
#  'Salary': '150000-220000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Senior Python Developer',
#  '_id': ObjectId('5d1fd12b99135287c93f0b41')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31952519?query=python',
#  'Salary': '150000-230000 руб.',
#  'Salary_Processed': 150000.0,
#  'Title': 'Python developer (Cloud Services)',
#  '_id': ObjectId('5d1fd12b99135287c93f0b45')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32072763?query=python',
#  'Salary': '160000-250000 руб.',
#  'Salary_Processed': 160000.0,
#  'Title': 'Python Developer',
#  '_id': ObjectId('5d1fd100f943af417829c7a5')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31624245?query=python',
#  'Salary': '160000-200000 руб.',
#  'Salary_Processed': 160000.0,
#  'Title': 'Разработчик Python',
#  '_id': ObjectId('5d1fd101f943af417829c7ab')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32317115?query=python',
#  'Salary': 'от 160000 руб.',
#  'Salary_Processed': 160000.0,
#  'Title': 'Программист / Ведущий программист Python',
#  '_id': ObjectId('5d1fd101f943af417829c7b3')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32072763?query=python',
#  'Salary': '160000-250000 руб.',
#  'Salary_Processed': 160000.0,
#  'Title': 'Python Developer',
#  '_id': ObjectId('5d1fd12b99135287c93f0b28')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31624245?query=python',
#  'Salary': '160000-200000 руб.',
#  'Salary_Processed': 160000.0,
#  'Title': 'Разработчик Python',
#  '_id': ObjectId('5d1fd12b99135287c93f0b2e')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32317115?query=python',
#  'Salary': 'от 160000 руб.',
#  'Salary_Processed': 160000.0,
#  'Title': 'Программист / Ведущий программист Python',
#  '_id': ObjectId('5d1fd12b99135287c93f0b36')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31929637?query=python',
#  'Salary': 'от 180000 руб.',
#  'Salary_Processed': 180000.0,
#  'Title': 'Разработчик Python и SQL',
#  '_id': ObjectId('5d1fd101f943af417829c7a9')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32152220?query=python',
#  'Salary': '180000-230000 руб.',
#  'Salary_Processed': 180000.0,
#  'Title': 'Senior Python developer (Cloud Services)',
#  '_id': ObjectId('5d1fd101f943af417829c7c1')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/31929637?query=python',
#  'Salary': 'от 180000 руб.',
#  'Salary_Processed': 180000.0,
#  'Title': 'Разработчик Python и SQL',
#  '_id': ObjectId('5d1fd12b99135287c93f0b2c')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32152220?query=python',
#  'Salary': '180000-230000 руб.',
#  'Salary_Processed': 180000.0,
#  'Title': 'Senior Python developer (Cloud Services)',
#  '_id': ObjectId('5d1fd12b99135287c93f0b44')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32096105?query=python',
#  'Salary': '200000-300000 руб.',
#  'Salary_Processed': 200000.0,
#  'Title': 'Python Web Developer',
#  '_id': ObjectId('5d1fd101f943af417829c7c3')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32256640?query=python',
#  'Salary': 'от 200000 руб.',
#  'Salary_Processed': 200000.0,
#  'Title': 'Ведущий разработчик Python на платежную платформу',
#  '_id': ObjectId('5d1fd101f943af417829c7c5')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32096105?query=python',
#  'Salary': '200000-300000 руб.',
#  'Salary_Processed': 200000.0,
#  'Title': 'Python Web Developer',
#  '_id': ObjectId('5d1fd12b99135287c93f0b46')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32256640?query=python',
#  'Salary': 'от 200000 руб.',
#  'Salary_Processed': 200000.0,
#  'Title': 'Ведущий разработчик Python на платежную платформу',
#  '_id': ObjectId('5d1fd12b99135287c93f0b48')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/30005963?query=python',
#  'Salary': 'от 4000 USD',
#  'Salary_Processed': 254320.0,
#  'Title': 'Python developer (Библиотеки для автотестирования)',
#  '_id': ObjectId('5d1fd101f943af417829c7b4')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/30005963?query=python',
#  'Salary': 'от 4000 USD',
#  'Salary_Processed': 254320.0,
#  'Title': 'Python developer (Библиотеки для автотестирования)',
#  '_id': ObjectId('5d1fd12b99135287c93f0b37')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32030680?query=python',
#  'Salary': '300000-400000 руб.',
#  'Salary_Processed': 300000.0,
#  'Title': 'Data Engineering Team Lead (Python / C++)',
#  '_id': ObjectId('5d1fd101f943af417829c7bf')}
# {'Href': 'https://vidnoe.hh.ru/vacancy/32030680?query=python',
#  'Salary': '300000-400000 руб.',
#  'Salary_Processed': 300000.0,
#  'Title': 'Data Engineering Team Lead (Python / C++)',
#  '_id': ObjectId('5d1fd12b99135287c93f0b42')}
